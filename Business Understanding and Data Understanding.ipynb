# %% [markdown]
# More travelers are considering Airbnb as a choice for accommodation. Also, more people who have spare rooms are using Airbnb as a new way to increase revenue. As travelers, they might care about what are the busiest times of the year to visit Seattle and how do the price change. As landord, one might care about how to increase the change that my listing being booked. I found  Seattle Airbnb Open Data on Kaggle and tried to find insightful information from it that can help travelers or landlords to better use Airbnb.

# %% [markdown]
# The data sauce provides three data files:
# Listings: includes full descriptions and average review score of all 3818 listings on Seattle Airbnb in 2016
# Reviews: includes unique id for each reviewer and detailed comments
# Calendar: includes listing id and the price and availability for each day in 2016
#
# Here, to answer questions I am interesed in, I only use 2 datasets: listings and calendar

# %% [markdown]
# Let's glance the dataset first

# %%
# import necessary library
import numpy as np
import pandas as pd

# import calendar dataset
calendar = pd.read_csv('calendar.csv')

# show the first few rows of calendar
calendar.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %% [markdown]
# The dataset provides information like whether specific listing is available on specific day and its price. We can use it to calculate the percent of available listings on each day and average price of booked listings on dach day. Looks like it has useful information for travelers.
#
# We can also use it to calculate the percent of booked days of each listing. This information might be helpful for landlords.

# %%
# import listings dataset and show first few rows
listing = pd.read_csv('listings.csv')
listing.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
listing.shape
# Out:
# (3818, 92)

# %%
listing.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %% [markdown]
# This dataset offers detail description of each listing. We can combine this dataset with the percent of booked days of each listing to find some suggestions for landlord to increase their listings' chance of being booked.
